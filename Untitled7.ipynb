# %%
import glob
import os.path
import os
import random
import numpy as np
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from keras.layers import Input,Dense
INPUT_DATA = 'rock_test_a'
VALIDATION_PERCENTAGE = 10  # 保留10%的数据用于验证
TEST_PERCENTAGE = 10  # 保留10%的数据用于测试
LEARNING_RATE = 0.01#学习率
BATCH = 32  # 迭代样本数量

# 数据增强配置
datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True)

# 载入所有图片路径和标签
def load_images_and_labels(image_lists):
    all_images = []
    all_labels = []
    for label_name, label_lists in image_lists.items():
        for category in ['training', 'testing', 'validation']:
            for image_name in label_lists[category]:
                image_path = os.path.join(INPUT_DATA, label_name, image_name)
                all_images.append(image_path)
                all_labels.append(label_name)
    return np.array(all_images), np.array(all_labels)



def create_rock_classification_model(num_classes):

    # 输入层
    input_tensor = Input(shape=(150, 150, 3))

    # 预训练的InceptionV3模型作为特征提取器，不包括顶部的全连接层
    base_model = InceptionV3(include_top=False, weights='imagenet', input_tensor=input_tensor)
    base_model.trainable = False  # 冻结预训练模型的权重

    # 添加自定义层
    x = base_model.output
    x = GlobalAveragePooling2D()(x)  # 添加全局平均池化层
    x = BatchNormalization()(x)      # 添加批量归一化层
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)  # 添加L2权重正则化
    x = Dropout(0.5)(x)              # 添加Dropout层，减少过拟合
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)  # 再次添加L2权重正则化
    x = Dropout(0.5)(x)
    
    # 输出层
    predictions = Dense(num_classes, activation='softmax', kernel_regularizer=l2(0.01))(x)  # 添加L2权重正则化

    # 构建最终模型
    model = Model(inputs=input_tensor, outputs=predictions)

    # 编译模型
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 打印模型摘要
    model.summary()

    return model


# 用于加载和预处理图片的函数
def load_and_preprocess_images(image_paths, target_size):
    images = [img_to_array(load_img(img, target_size=target_size)) for img in image_paths]
    return np.array(images)

# 将数据分割为交叉验证的训练和测试集
def get_data_for_fold(fold_num, skf, all_images, all_labels, num_classes):
    train_indices, test_indices = list(skf.split(all_images, all_labels))[fold_num]
    train_images = [all_images[i] for i in train_indices]
    test_images = [all_images[i] for i in test_indices]
    train_labels = to_categorical([all_labels[i] for i in train_indices], num_classes=num_classes)
    test_labels = to_categorical([all_labels[i] for i in test_indices], num_classes=num_classes)

    # 加载和预处理图片
    train_images = load_and_preprocess_images(train_images, target_size=(150, 150))
    test_images = load_and_preprocess_images(test_images, target_size=(150, 150))

    return train_images, train_labels, test_images, test_labels

# 使用交叉验证进行模型训练和评估的函数
def cross_validate(image_lists, num_classes, k=5):
    all_images, all_labels = load_images_and_labels(image_lists)
    label_to_int = {label: index for index, label in enumerate(np.unique(all_labels))}
    all_labels = np.array([label_to_int[label] for label in all_labels])

    skf = StratifiedKFold(n_splits=k, shuffle=True)
    fold_number = 0
    for fold in range(k):
        # 获取当前fold的数据
        train_images, train_labels, test_images, test_labels = get_data_for_fold(fold, skf, all_images, all_labels, num_classes)

        # 创建数据生成器
        train_datagen = datagen.flow(train_images, train_labels, batch_size=BATCH)
        test_datagen = ImageDataGenerator(rescale=1./255).flow(test_images, test_labels, batch_size=BATCH)

        # 创建新的模型实例
        model = create_rock_classification_model(num_classes)

        # 训练模型
        model.fit(
        train_datagen,
        steps_per_epoch=len(train_images) // BATCH,
        epochs=20,
        validation_data=test_datagen,
        validation_steps=len(test_images) // BATCH)

       # 在测试集上进行预测
        test_predictions = model.predict(test_images)  # 直接使用测试集图像，不再使用 test_datagen
        predicted_labels = np.argmax(test_predictions, axis=1)
        true_labels = np.argmax(test_labels, axis=1)

        # 计算混淆矩阵和每个类别的准确率
        conf_matrix = confusion_matrix(true_labels, predicted_labels)
        class_report = classification_report(true_labels, predicted_labels)

        print(f"Confusion Matrix for fold {fold_number}:\n", conf_matrix)
        print(f"Classification Report for fold {fold_number}:\n", class_report)

        # 计算整体准确率
        overall_accuracy = np.sum(np.diag(conf_matrix)) / np.sum(conf_matrix)
        print(f'Overall Accuracy for fold {fold_number}: {overall_accuracy}')

        fold_number += 1
        model.save(f'rock_fold_{fold_number}.h5')





def create_image_lists(validation_pct, test_pct):
    # 初始化一个空字典以存储图像列表
    result = {}
    
    # 获取指定输入目录中所有子目录（文件夹）的列表
    sub_dirs = [x[0] for x in os.walk(INPUT_DATA)]
    
    # 标志，用于检查当前子目录是否是根目录
    is_root_dir = True
    
    # 遍历每个子目录
    for sub_dir in sub_dirs:
        # 跳过根目录
        if is_root_dir:
            is_root_dir = False
            continue
        
        # 定义要考虑的文件扩展名列表（图片）
        extensions = ['jpg', 'jpeg', 'JPG', 'JPEG']
        
        # 初始化一个空列表以存储文件路径
        file_list = []
        
        # 从当前子目录中提取基本名称
        dir_name = os.path.basename(sub_dir)
        
        # 遍历每个文件扩展名
        for extension in extensions:
            # 创建文件glob模式，以匹配具有当前扩展名的文件
            file_glob = os.path.join(sub_dir, '*.' + extension)
            
            # 使用glob获取与模式匹配的文件路径列表
            file_list.extend(glob.glob(file_glob))
        
        # 检查当前子目录中是否有任何文件
        if not file_list:
            continue
        
        # 从当前子目录中提取标签名称
        label_name = os.path.basename(sub_dir)
        
        # 初始化列表以存储训练、测试和验证图像
        training_images = []
        testing_images = []
        validation_images = []
        
        # 遍历文件列表中的每个文件
        for file_name in file_list:
            # 提取文件的基本名称
            base_name = os.path.basename(file_name)
            
            # 生成介于0和99之间的随机数
            chance = np.random.randint(100)
            
            # 根据随机数将文件分配到训练、测试或验证集中
            if chance < validation_pct:
                validation_images.append(base_name)
            elif chance < (test_pct + validation_pct):
                testing_images.append(base_name)
            else:
                training_images.append(base_name)
        
        # 将结果存储在当前标签的字典中
        result[label_name] = {
            'dir': dir_name,
            'training': training_images,
            'testing': testing_images,
            'validation': validation_images,
        }
    
    # 返回包含图像列表的最终字典
    return result



if __name__ == '__main__':
    # 读取所有的图片并创建图像列表
    image_lists = create_image_lists(VALIDATION_PERCENTAGE, TEST_PERCENTAGE)
    n_classes = len(image_lists.keys())
    # 应用交叉验证来训练和评估模型
    cross_validate(image_lists, n_classes, k=5)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  conv2d_376 (Conv2D)         (None, 74, 74, 32)           864       ['input_5[0][0]']
#
#  batch_normalization_381 (B  (None, 74, 74, 32)           96        ['conv2d_376[0][0]']
#  atchNormalization)
#
#  activation_376 (Activation  (None, 74, 74, 32)           0         ['batch_normalization_381[0][0
#  )                                                                  ]']
#
#  conv2d_377 (Conv2D)         (None, 72, 72, 32)           9216      ['activation_376[0][0]']
#
#  batch_normalization_382 (B  (None, 72, 72, 32)           96        ['conv2d_377[0][0]']
#  atchNormalization)
#
#  activation_377 (Activation  (None, 72, 72, 32)           0         ['batch_normalization_382[0][0
#  )                                                                  ]']
#
#  conv2d_378 (Conv2D)         (None, 72, 72, 64)           18432     ['activation_377[0][0]']
#
#  batch_normalization_383 (B  (None, 72, 72, 64)           192       ['conv2d_378[0][0]']
#  atchNormalization)
#
#  activation_378 (Activation  (None, 72, 72, 64)           0         ['batch_normalization_383[0][0
#  )                                                                  ]']
#
#  max_pooling2d_16 (MaxPooli  (None, 35, 35, 64)           0         ['activation_378[0][0]']
#  ng2D)
#
#  conv2d_379 (Conv2D)         (None, 35, 35, 80)           5120      ['max_pooling2d_16[0][0]']
#
#  batch_normalization_384 (B  (None, 35, 35, 80)           240       ['conv2d_379[0][0]']
#  atchNormalization)
#
#  activation_379 (Activation  (None, 35, 35, 80)           0         ['batch_normalization_384[0][0
#  )                                                                  ]']
#
#  conv2d_380 (Conv2D)         (None, 33, 33, 192)          138240    ['activation_379[0][0]']
#
#  batch_normalization_385 (B  (None, 33, 33, 192)          576       ['conv2d_380[0][0]']
#  atchNormalization)
#
#  activation_380 (Activation  (None, 33, 33, 192)          0         ['batch_normalization_385[0][0
#  )                                                                  ]']
#
#  max_pooling2d_17 (MaxPooli  (None, 16, 16, 192)          0         ['activation_380[0][0]']
#  ng2D)
#
#  conv2d_384 (Conv2D)         (None, 16, 16, 64)           12288     ['max_pooling2d_17[0][0]']
#
#  batch_normalization_389 (B  (None, 16, 16, 64)           192       ['conv2d_384[0][0]']
#  atchNormalization)
#
#  activation_384 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_389[0][0
#  )                                                                  ]']
#
#  conv2d_382 (Conv2D)         (None, 16, 16, 48)           9216      ['max_pooling2d_17[0][0]']
#
#  conv2d_385 (Conv2D)         (None, 16, 16, 96)           55296     ['activation_384[0][0]']
#
#  batch_normalization_387 (B  (None, 16, 16, 48)           144       ['conv2d_382[0][0]']
#  atchNormalization)
#
#  batch_normalization_390 (B  (None, 16, 16, 96)           288       ['conv2d_385[0][0]']
#  atchNormalization)
#
#  activation_382 (Activation  (None, 16, 16, 48)           0         ['batch_normalization_387[0][0
#  )                                                                  ]']
#
#  activation_385 (Activation  (None, 16, 16, 96)           0         ['batch_normalization_390[0][0
#  )                                                                  ]']
#
#  average_pooling2d_36 (Aver  (None, 16, 16, 192)          0         ['max_pooling2d_17[0][0]']
#  agePooling2D)
#
#  conv2d_381 (Conv2D)         (None, 16, 16, 64)           12288     ['max_pooling2d_17[0][0]']
#
#  conv2d_383 (Conv2D)         (None, 16, 16, 64)           76800     ['activation_382[0][0]']
#
#  conv2d_386 (Conv2D)         (None, 16, 16, 96)           82944     ['activation_385[0][0]']
#
#  conv2d_387 (Conv2D)         (None, 16, 16, 32)           6144      ['average_pooling2d_36[0][0]']
#
#  batch_normalization_386 (B  (None, 16, 16, 64)           192       ['conv2d_381[0][0]']
#  atchNormalization)
#
#  batch_normalization_388 (B  (None, 16, 16, 64)           192       ['conv2d_383[0][0]']
#  atchNormalization)
#
#  batch_normalization_391 (B  (None, 16, 16, 96)           288       ['conv2d_386[0][0]']
#  atchNormalization)
#
#  batch_normalization_392 (B  (None, 16, 16, 32)           96        ['conv2d_387[0][0]']
#  atchNormalization)
#
#  activation_381 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_386[0][0
#  )                                                                  ]']
#
#  activation_383 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_388[0][0
#  )                                                                  ]']
#
#  activation_386 (Activation  (None, 16, 16, 96)           0         ['batch_normalization_391[0][0
#  )                                                                  ]']
#
#  activation_387 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_392[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 16, 16, 256)          0         ['activation_381[0][0]',
#                                                                      'activation_383[0][0]',
#                                                                      'activation_386[0][0]',
#                                                                      'activation_387[0][0]']
#
#  conv2d_391 (Conv2D)         (None, 16, 16, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_396 (B  (None, 16, 16, 64)           192       ['conv2d_391[0][0]']
#  atchNormalization)
#
#  activation_391 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_396[0][0
#  )                                                                  ]']
#
#  conv2d_389 (Conv2D)         (None, 16, 16, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_392 (Conv2D)         (None, 16, 16, 96)           55296     ['activation_391[0][0]']
#
#  batch_normalization_394 (B  (None, 16, 16, 48)           144       ['conv2d_389[0][0]']
#  atchNormalization)
#
#  batch_normalization_397 (B  (None, 16, 16, 96)           288       ['conv2d_392[0][0]']
#  atchNormalization)
#
#  activation_389 (Activation  (None, 16, 16, 48)           0         ['batch_normalization_394[0][0
#  )                                                                  ]']
#
#  activation_392 (Activation  (None, 16, 16, 96)           0         ['batch_normalization_397[0][0
#  )                                                                  ]']
#
#  average_pooling2d_37 (Aver  (None, 16, 16, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_388 (Conv2D)         (None, 16, 16, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_390 (Conv2D)         (None, 16, 16, 64)           76800     ['activation_389[0][0]']
#
#  conv2d_393 (Conv2D)         (None, 16, 16, 96)           82944     ['activation_392[0][0]']
#
#  conv2d_394 (Conv2D)         (None, 16, 16, 64)           16384     ['average_pooling2d_37[0][0]']
#
#  batch_normalization_393 (B  (None, 16, 16, 64)           192       ['conv2d_388[0][0]']
#  atchNormalization)
#
#  batch_normalization_395 (B  (None, 16, 16, 64)           192       ['conv2d_390[0][0]']
#  atchNormalization)
#
#  batch_normalization_398 (B  (None, 16, 16, 96)           288       ['conv2d_393[0][0]']
#  atchNormalization)
#
#  batch_normalization_399 (B  (None, 16, 16, 64)           192       ['conv2d_394[0][0]']
#  atchNormalization)
#
#  activation_388 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_393[0][0
#  )                                                                  ]']
#
#  activation_390 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_395[0][0
#  )                                                                  ]']
#
#  activation_393 (Activation  (None, 16, 16, 96)           0         ['batch_normalization_398[0][0
#  )                                                                  ]']
#
#  activation_394 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_399[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 16, 16, 288)          0         ['activation_388[0][0]',
#                                                                      'activation_390[0][0]',
#                                                                      'activation_393[0][0]',
#                                                                      'activation_394[0][0]']
#
#  conv2d_398 (Conv2D)         (None, 16, 16, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_403 (B  (None, 16, 16, 64)           192       ['conv2d_398[0][0]']
#  atchNormalization)
#
#  activation_398 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_403[0][0
#  )                                                                  ]']
#
#  conv2d_396 (Conv2D)         (None, 16, 16, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_399 (Conv2D)         (None, 16, 16, 96)           55296     ['activation_398[0][0]']
#
#  batch_normalization_401 (B  (None, 16, 16, 48)           144       ['conv2d_396[0][0]']
#  atchNormalization)
#
#  batch_normalization_404 (B  (None, 16, 16, 96)           288       ['conv2d_399[0][0]']
#  atchNormalization)
#
#  activation_396 (Activation  (None, 16, 16, 48)           0         ['batch_normalization_401[0][0
#  )                                                                  ]']
#
#  activation_399 (Activation  (None, 16, 16, 96)           0         ['batch_normalization_404[0][0
#  )                                                                  ]']
#
#  average_pooling2d_38 (Aver  (None, 16, 16, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_395 (Conv2D)         (None, 16, 16, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_397 (Conv2D)         (None, 16, 16, 64)           76800     ['activation_396[0][0]']
#
#  conv2d_400 (Conv2D)         (None, 16, 16, 96)           82944     ['activation_399[0][0]']
#
#  conv2d_401 (Conv2D)         (None, 16, 16, 64)           18432     ['average_pooling2d_38[0][0]']
#
#  batch_normalization_400 (B  (None, 16, 16, 64)           192       ['conv2d_395[0][0]']
#  atchNormalization)
#
#  batch_normalization_402 (B  (None, 16, 16, 64)           192       ['conv2d_397[0][0]']
#  atchNormalization)
#
#  batch_normalization_405 (B  (None, 16, 16, 96)           288       ['conv2d_400[0][0]']
#  atchNormalization)
#
#  batch_normalization_406 (B  (None, 16, 16, 64)           192       ['conv2d_401[0][0]']
#  atchNormalization)
#
#  activation_395 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_400[0][0
#  )                                                                  ]']
#
#  activation_397 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_402[0][0
#  )                                                                  ]']
#
#  activation_400 (Activation  (None, 16, 16, 96)           0         ['batch_normalization_405[0][0
#  )                                                                  ]']
#
#  activation_401 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_406[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 16, 16, 288)          0         ['activation_395[0][0]',
#                                                                      'activation_397[0][0]',
#                                                                      'activation_400[0][0]',
#                                                                      'activation_401[0][0]']
#
#  conv2d_403 (Conv2D)         (None, 16, 16, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_408 (B  (None, 16, 16, 64)           192       ['conv2d_403[0][0]']
#  atchNormalization)
#
#  activation_403 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_408[0][0
#  )                                                                  ]']
#
#  conv2d_404 (Conv2D)         (None, 16, 16, 96)           55296     ['activation_403[0][0]']
#
#  batch_normalization_409 (B  (None, 16, 16, 96)           288       ['conv2d_404[0][0]']
#  atchNormalization)
#
#  activation_404 (Activation  (None, 16, 16, 96)           0         ['batch_normalization_409[0][0
#  )                                                                  ]']
#
#  conv2d_402 (Conv2D)         (None, 7, 7, 384)            995328    ['mixed2[0][0]']
#
#  conv2d_405 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_404[0][0]']
#
#  batch_normalization_407 (B  (None, 7, 7, 384)            1152      ['conv2d_402[0][0]']
#  atchNormalization)
#
#  batch_normalization_410 (B  (None, 7, 7, 96)             288       ['conv2d_405[0][0]']
#  atchNormalization)
#
#  activation_402 (Activation  (None, 7, 7, 384)            0         ['batch_normalization_407[0][0
#  )                                                                  ]']
#
#  activation_405 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_410[0][0
#  )                                                                  ]']
#
#  max_pooling2d_18 (MaxPooli  (None, 7, 7, 288)            0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 7, 7, 768)            0         ['activation_402[0][0]',
#                                                                      'activation_405[0][0]',
#                                                                      'max_pooling2d_18[0][0]']
#
#  conv2d_410 (Conv2D)         (None, 7, 7, 128)            98304     ['mixed3[0][0]']
#
#  batch_normalization_415 (B  (None, 7, 7, 128)            384       ['conv2d_410[0][0]']
#  atchNormalization)
#
#  activation_410 (Activation  (None, 7, 7, 128)            0         ['batch_normalization_415[0][0
#  )                                                                  ]']
#
#  conv2d_411 (Conv2D)         (None, 7, 7, 128)            114688    ['activation_410[0][0]']
#
#  batch_normalization_416 (B  (None, 7, 7, 128)            384       ['conv2d_411[0][0]']
#  atchNormalization)
#
#  activation_411 (Activation  (None, 7, 7, 128)            0         ['batch_normalization_416[0][0
#  )                                                                  ]']
#
#  conv2d_407 (Conv2D)         (None, 7, 7, 128)            98304     ['mixed3[0][0]']
#
#  conv2d_412 (Conv2D)         (None, 7, 7, 128)            114688    ['activation_411[0][0]']
#
#  batch_normalization_412 (B  (None, 7, 7, 128)            384       ['conv2d_407[0][0]']
#  atchNormalization)
#
#  batch_normalization_417 (B  (None, 7, 7, 128)            384       ['conv2d_412[0][0]']
#  atchNormalization)
#
#  activation_407 (Activation  (None, 7, 7, 128)            0         ['batch_normalization_412[0][0
#  )                                                                  ]']
#
#  activation_412 (Activation  (None, 7, 7, 128)            0         ['batch_normalization_417[0][0
#  )                                                                  ]']
#
#  conv2d_408 (Conv2D)         (None, 7, 7, 128)            114688    ['activation_407[0][0]']
#
#  conv2d_413 (Conv2D)         (None, 7, 7, 128)            114688    ['activation_412[0][0]']
#
#  batch_normalization_413 (B  (None, 7, 7, 128)            384       ['conv2d_408[0][0]']
#  atchNormalization)
#
#  batch_normalization_418 (B  (None, 7, 7, 128)            384       ['conv2d_413[0][0]']
#  atchNormalization)
#
#  activation_408 (Activation  (None, 7, 7, 128)            0         ['batch_normalization_413[0][0
#  )                                                                  ]']
#
#  activation_413 (Activation  (None, 7, 7, 128)            0         ['batch_normalization_418[0][0
#  )                                                                  ]']
#
#  average_pooling2d_39 (Aver  (None, 7, 7, 768)            0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_406 (Conv2D)         (None, 7, 7, 192)            147456    ['mixed3[0][0]']
#
#  conv2d_409 (Conv2D)         (None, 7, 7, 192)            172032    ['activation_408[0][0]']
#
#  conv2d_414 (Conv2D)         (None, 7, 7, 192)            172032    ['activation_413[0][0]']
#
#  conv2d_415 (Conv2D)         (None, 7, 7, 192)            147456    ['average_pooling2d_39[0][0]']
#
#  batch_normalization_411 (B  (None, 7, 7, 192)            576       ['conv2d_406[0][0]']
#  atchNormalization)
#
#  batch_normalization_414 (B  (None, 7, 7, 192)            576       ['conv2d_409[0][0]']
#  atchNormalization)
#
#  batch_normalization_419 (B  (None, 7, 7, 192)            576       ['conv2d_414[0][0]']
#  atchNormalization)
#
#  batch_normalization_420 (B  (None, 7, 7, 192)            576       ['conv2d_415[0][0]']
#  atchNormalization)
#
#  activation_406 (Activation  (None, 7, 7, 192)            0         ['batch_normalization_411[0][0
#  )                                                                  ]']
#
#  activation_409 (Activation  (None, 7, 7, 192)            0         ['batch_normalization_414[0][0
#  )                                                                  ]']
#
#  activation_414 (Activation  (None, 7, 7, 192)            0         ['batch_normalization_419[0][0
#  )                                                                  ]']
#
#  activation_415 (Activation  (None, 7, 7, 192)            0         ['batch_normalization_420[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 7, 7, 768)            0         ['activation_406[0][0]',
#                                                                      'activation_409[0][0]',
#                                                                      'activation_414[0][0]',
#                                                                      'activation_415[0][0]']
#
#  conv2d_420 (Conv2D)         (None, 7, 7, 160)            122880    ['mixed4[0][0]']
#
#  batch_normalization_425 (B  (None, 7, 7, 160)            480       ['conv2d_420[0][0]']
#  atchNormalization)
#
#  activation_420 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_425[0][0
#  )                                                                  ]']
#
#  conv2d_421 (Conv2D)         (None, 7, 7, 160)            179200    ['activation_420[0][0]']
#
#  batch_normalization_426 (B  (None, 7, 7, 160)            480       ['conv2d_421[0][0]']
#  atchNormalization)
#
#  activation_421 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_426[0][0
#  )                                                                  ]']
#
#  conv2d_417 (Conv2D)         (None, 7, 7, 160)            122880    ['mixed4[0][0]']
#
#  conv2d_422 (Conv2D)         (None, 7, 7, 160)            179200    ['activation_421[0][0]']
#
#  batch_normalization_422 (B  (None, 7, 7, 160)            480       ['conv2d_417[0][0]']
#  atchNormalization)
#
#  batch_normalization_427 (B  (None, 7, 7, 160)            480       ['conv2d_422[0][0]']
#  atchNormalization)
#
#  activation_417 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_422[0][0
#  )                                                                  ]']
#
#  activation_422 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_427[0][0
#  )                                                                  ]']
#
#  conv2d_418 (Conv2D)         (None, 7, 7, 160)            179200    ['activation_417[0][0]']
#
#  conv2d_423 (Conv2D)         (None, 7, 7, 160)            179200    ['activation_422[0][0]']
#
#  batch_normalization_423 (B  (None, 7, 7, 160)            480       ['conv2d_418[0][0]']
#  atchNormalization)
#
#  batch_normalization_428 (B  (None, 7, 7, 160)            480       ['conv2d_423[0][0]']
#  atchNormalization)
#
#  activation_418 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_423[0][0
#  )                                                                  ]']
#
#  activation_423 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_428[0][0
#  )                                                                  ]']
#
#  average_pooling2d_40 (Aver  (None, 7, 7, 768)            0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_416 (Conv2D)         (None, 7, 7, 192)            147456    ['mixed4[0][0]']
#
#  conv2d_419 (Conv2D)         (None, 7, 7, 192)            215040    ['activation_418[0][0]']
#
#  conv2d_424 (Conv2D)         (None, 7, 7, 192)            215040    ['activation_423[0][0]']
#
#  conv2d_425 (Conv2D)         (None, 7, 7, 192)            147456    ['average_pooling2d_40[0][0]']
#
#  batch_normalization_421 (B  (None, 7, 7, 192)            576       ['conv2d_416[0][0]']
#  atchNormalization)
#
#  batch_normalization_424 (B  (None, 7, 7, 192)            576       ['conv2d_419[0][0]']
#  atchNormalization)
#
#  batch_normalization_429 (B  (None, 7, 7, 192)            576       ['conv2d_424[0][0]']
#  atchNormalization)
#
#  batch_normalization_430 (B  (None, 7, 7, 192)            576       ['conv2d_425[0][0]']
#  atchNormalization)
#
#  activation_416 (Activation  (None, 7, 7, 192)            0         ['batch_normalization_421[0][0
#  )                                                                  ]']
#
#  activation_419 (Activation  (None, 7, 7, 192)            0         ['batch_normalization_424[0][0
#  )                                                                  ]']
#
#  activation_424 (Activation  (None, 7, 7, 192)            0         ['batch_normalization_429[0][0
#  )                                                                  ]']
#
#  activation_425 (Activation  (None, 7, 7, 192)            0         ['batch_normalization_430[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 7, 7, 768)            0         ['activation_416[0][0]',
#                                                                      'activation_419[0][0]',
#                                                                      'activation_424[0][0]',
#                                                                      'activation_425[0][0]']
#
#  conv2d_430 (Conv2D)         (None, 7, 7, 160)            122880    ['mixed5[0][0]']
#
#  batch_normalization_435 (B  (None, 7, 7, 160)            480       ['conv2d_430[0][0]']
#  atchNormalization)
#
#  activation_430 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_435[0][0
#  )                                                                  ]']
#
#  conv2d_431 (Conv2D)         (None, 7, 7, 160)            179200    ['activation_430[0][0]']
#
#  batch_normalization_436 (B  (None, 7, 7, 160)            480       ['conv2d_431[0][0]']
#  atchNormalization)
#
#  activation_431 (Activation  (None, 7, 7, 160)            0         ['batch_normalization_436[0][0
#  )                                                                  ]']
#
#  conv2d_427 (Conv2D)         (None, 7, 7, 160)            122880    ['mixed5[0][0]']
#
#  conv2d_432 (Conv2D)         (None, 7, 7, 160)            179200    ['activation_431[0][0]']
#
#  batch_normalization_432 (B  (None, 7, 7, 160)            480       ['conv2d_427[0][0]']
#  atchNormalization)
#
#  batch_normalization_437 (B  (None, 7, 7, 160)            480       ['conv2d_432[0][0]']
#  atchNormalization)
#
# ...
#  batch_normalization_563 (B  (None, 3, 3, 384)            1152      ['conv2d_556[0][0]']
#  atchNormalization)
#
#  batch_normalization_567 (B  (None, 3, 3, 384)            1152      ['conv2d_560[0][0]']
#  atchNormalization)
#
#  activation_556 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_563[0][0
#  )                                                                  ]']
#
#  activation_560 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_567[0][0
#  )                                                                  ]']
#
#  conv2d_557 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_556[0][0]']
#
#  conv2d_558 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_556[0][0]']
#
#  conv2d_561 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_560[0][0]']
#
#  conv2d_562 (Conv2D)         (None, 3, 3, 384)            442368    ['activation_560[0][0]']
#
#  average_pooling2d_53 (Aver  (None, 3, 3, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_555 (Conv2D)         (None, 3, 3, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_564 (B  (None, 3, 3, 384)            1152      ['conv2d_557[0][0]']
#  atchNormalization)
#
#  batch_normalization_565 (B  (None, 3, 3, 384)            1152      ['conv2d_558[0][0]']
#  atchNormalization)
#
#  batch_normalization_568 (B  (None, 3, 3, 384)            1152      ['conv2d_561[0][0]']
#  atchNormalization)
#
#  batch_normalization_569 (B  (None, 3, 3, 384)            1152      ['conv2d_562[0][0]']
#  atchNormalization)
#
#  conv2d_563 (Conv2D)         (None, 3, 3, 192)            393216    ['average_pooling2d_53[0][0]']
#
#  batch_normalization_562 (B  (None, 3, 3, 320)            960       ['conv2d_555[0][0]']
#  atchNormalization)
#
#  activation_557 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_564[0][0
#  )                                                                  ]']
#
#  activation_558 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_565[0][0
#  )                                                                  ]']
#
#  activation_561 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_568[0][0
#  )                                                                  ]']
#
#  activation_562 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_569[0][0
#  )                                                                  ]']
#
#  batch_normalization_570 (B  (None, 3, 3, 192)            576       ['conv2d_563[0][0]']
#  atchNormalization)
#
#  activation_555 (Activation  (None, 3, 3, 320)            0         ['batch_normalization_562[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 3, 3, 768)            0         ['activation_557[0][0]',
#                                                                      'activation_558[0][0]']
#
#  concatenate_11 (Concatenat  (None, 3, 3, 768)            0         ['activation_561[0][0]',
#  e)                                                                  'activation_562[0][0]']
#
#  activation_563 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_570[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 3, 3, 2048)           0         ['activation_555[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_11[0][0]',
#                                                                      'activation_563[0][0]']
#
#  global_average_pooling2d_4  (None, 2048)                 0         ['mixed10[0][0]']
#   (GlobalAveragePooling2D)
#
#  batch_normalization_571 (B  (None, 2048)                 8192      ['global_average_pooling2d_4[0
#  atchNormalization)                                                 ][0]']
#
#  dense_9 (Dense)             (None, 512)                  1049088   ['batch_normalization_571[0][0
#                                                                     ]']
#
#  dropout_6 (Dropout)         (None, 512)                  0         ['dense_9[0][0]']
#
#  batch_normalization_572 (B  (None, 512)                  2048      ['dropout_6[0][0]']
#  atchNormalization)
#
#  dense_10 (Dense)            (None, 512)                  262656    ['batch_normalization_572[0][0
#                                                                     ]']
#
#  dropout_7 (Dropout)         (None, 512)                  0         ['dense_10[0][0]']
#
#  dense_11 (Dense)            (None, 3)                    1539      ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 23126307 (88.22 MB)
# Trainable params: 1318403 (5.03 MB)
# Non-trainable params: 21807904 (83.19 MB)
# __________________________________________________________________________________________________
# Epoch 1/20
# 67/67 [==============================] - 38s 496ms/step - loss: 12.4889 - accuracy: 0.5107 - val_loss: 9.9440 - val_accuracy: 0.6758
# Epoch 2/20
# 67/67 [==============================] - 31s 458ms/step - loss: 8.3239 - accuracy: 0.6409 - val_loss: 6.6619 - val_accuracy: 0.7051
# Epoch 3/20
# 49/67 [====================>.........] - ETA: 7s - loss: 5.9440 - accuracy: 0.6703
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 233
#     231 n_classes = len(image_lists.keys())
#     232 # 应用交叉验证来训练和评估模型
# --> 233 cross_validate(image_lists, n_classes, k=5)
#
# Cell In[9], line 123, in cross_validate(image_lists, num_classes, k)
#     120  model = create_rock_classification_model(num_classes)
#     122  # 训练模型
# --> 123  model.fit(
#     124  train_datagen,
#     125  steps_per_epoch=len(train_images) // BATCH,
#     126  epochs=20,
#     127  validation_data=test_datagen,
#     128  validation_steps=len(test_images) // BATCH)
#     130 # 在测试集上进行预测
#     131  test_predictions = model.predict(test_images)  # 直接使用测试集图像，不再使用 test_datagen
#
# File E:\python\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File E:\python\lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File E:\python\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File E:\python\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File E:\python\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File E:\python\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File E:\python\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File E:\python\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File E:\python\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File E:\python\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
